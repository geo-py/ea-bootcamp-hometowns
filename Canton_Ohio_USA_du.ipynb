# %% [markdown]
# **Hometown: Canton, Ohio, USA**  ![image.png](attachment:image.png)
#
# Canton is located in northeast Ohio, 60 miles southeast of Cleveland. It's where I grew up. The population is approximately 400,000. The most popular site is the Pro Football Hall of Fame. https://en.wikipedia.org/wiki/Canton,_Ohio
